# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto=pd.read_csv('tele.csv')

# %%
auto
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # compare churn count with respect to gender

# %%
sns.countplot(x="gender",hue="Churn",data=auto)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # find out how many female senior citizens there in the dataset

# %%
abc=auto.loc[(auto["gender"]=="Female") & (auto["SeniorCitizen"]==1)]
abc
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %% [markdown]
# # compare tenure with total charges

# %%
plt.scatter(auto["tenure"],auto["TotalCharges"],s=10,marker='^')
plt.xlabel("tenure")
plt.ylabel("TotalCharges")
plt.title("GRAPH BETWEEN TENURE VS TOTAL CHARGES")
# Out:
# Text(0.5, 1.0, 'GRAPH BETWEEN TENURE VS TOTAL CHARGES')

# %% [markdown]
# # findout which contract is preferred by the senior citizen

# %%
abc=auto.loc[(auto['SeniorCitizen']==1)]
abc.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV    Male              1      No         No       1           No
# 30  3841-NFECX  Female              1     Yes         No      71          Yes
# 31  4929-XIHVW    Male              1     Yes         No       2          Yes
# 34  3413-BMNZE    Male              1      No         No       1          Yes
# 50  8012-SOUDQ  Female              1      No         No      43          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 30               Yes     Fiber optic            Yes  ...              Yes
# 31                No     Fiber optic             No  ...              Yes
# 34                No             DSL             No  ...               No
# 50               Yes     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # comment on your finds on payment

# %%
sns.countplot(auto["PaymentMethod"],hue=auto["gender"])
plt.xticks(rotation=45)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])
