# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('pollu.csv')
data.head(5)
# Out:
#          Date  Year  Month  Day                                  Address  \
# 0  01-01-2000  2000      1    1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1  02-01-2000  2000      1    2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2  03-01-2000  2000      1    3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3  04-01-2000  2000      1    4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4  05-01-2000  2000      1    5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
#
#      State    County     City   O3 Mean  O3 1st Max Value  ...  \
# 0  Arizona  Maricopa  Phoenix  0.019765             0.040  ...
# 1  Arizona  Maricopa  Phoenix  0.015882             0.032  ...
# 2  Arizona  Maricopa  Phoenix  0.009353             0.016  ...
# 3  Arizona  Maricopa  Phoenix  0.015882             0.033  ...
# 4  Arizona  Maricopa  Phoenix  0.007353             0.012  ...
#
#    CO 1st Max Hour  CO AQI  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  \
# ...

# %%
#DATA UNDERSTANDING

# %%
data.tail()
# Out:
#               Date  Year  Month  Day                                Address  \
# 608694  26-06-2021  2021      6   26  NCore - North Cheyenne Soccer Complex
# 608695  27-06-2021  2021      6   27  NCore - North Cheyenne Soccer Complex
# 608696  28-06-2021  2021      6   28  NCore - North Cheyenne Soccer Complex
# 608697  29-06-2021  2021      6   29  NCore - North Cheyenne Soccer Complex
# 608698  30-06-2021  2021      6   30  NCore - North Cheyenne Soccer Complex
#
#           State   County           City   O3 Mean  O3 1st Max Value  ...  \
# 608694  Wyoming  Laramie  Not in a city  0.040588             0.049  ...
# 608695  Wyoming  Laramie  Not in a city  0.037882             0.042  ...
# 608696  Wyoming  Laramie  Not in a city  0.039765             0.050  ...
# 608697  Wyoming  Laramie  Not in a city  0.049176             0.058  ...
# 608698  Wyoming  Laramie  Not in a city  0.052333             0.054  ...
#
#         CO 1st Max Hour  CO AQI  SO2 Mean  SO2 1st Max Value  \
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Day', 'Address', 'State', 'County', 'City',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'CO Mean',
#        'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI', 'SO2 Mean',
#        'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608699 entries, 0 to 608698
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               608699 non-null  object
#  1   Year               608699 non-null  int64
#  2   Month              608699 non-null  int64
#  3   Day                608699 non-null  int64
#  4   Address            608699 non-null  object
#  5   State              608699 non-null  object
#  6   County             608699 non-null  object
#  7   City               608699 non-null  object
#  8   O3 Mean            608699 non-null  float64
#  9   O3 1st Max Value   608699 non-null  float64
#  10  O3 1st Max Hour    608699 non-null  int64
#  11  O3 AQI             608699 non-null  int64
#  12  CO Mean            608699 non-null  float64
#  13  CO 1st Max Value   608699 non-null  float64
#  14  CO 1st Max Hour    608699 non-null  int64
# ...

# %%
data.shape
# Out:
# (608699, 24)

# %%
data.count()
# Out:
# Date                 608699
# Year                 608699
# Month                608699
# Day                  608699
# Address              608699
# State                608699
# County               608699
# City                 608699
# O3 Mean              608699
# O3 1st Max Value     608699
# O3 1st Max Hour      608699
# O3 AQI               608699
# CO Mean              608699
# CO 1st Max Value     608699
# CO 1st Max Hour      608699
# CO AQI               608699
# SO2 Mean             608699
# SO2 1st Max Value    608699
# SO2 1st Max Hour     608699
# SO2 AQI              608699
# NO2 Mean             608699
# NO2 1st Max Value    608699
# NO2 1st Max Hour     608699
# NO2 AQI              608699
# dtype: int64

# %%
data.describe()
# Out:
#                 Year          Month            Day        O3 Mean  \
# count  608699.000000  608699.000000  608699.000000  608699.000000
# mean     2011.040529       6.508670      15.737176       0.028477
# std         6.122558       3.310633       8.806949       0.012218
# min      2000.000000       1.000000       1.000000      -0.000706
# 25%      2006.000000       4.000000       8.000000       0.019647
# 50%      2012.000000       7.000000      16.000000       0.028235
# 75%      2016.000000       9.000000      23.000000       0.036765
# max      2021.000000      12.000000      31.000000       0.107353
#
#        O3 1st Max Value  O3 1st Max Hour         O3 AQI        CO Mean  \
# count     608699.000000    608699.000000  608699.000000  608699.000000
# mean           0.038903        10.773469      39.112517       0.337258
# std            0.015031         3.308152      22.480864       0.282958
# min            0.000000         7.000000       0.000000      -0.437500
# ...

# %%
data.apply(lambda x:len(x.unique()))
# Out:
# Date                  7975
# Year                    22
# Month                   12
# Day                     31
# Address                216
# State                   48
# County                 136
# City                   148
# O3 Mean               5634
# O3 1st Max Value       134
# O3 1st Max Hour         17
# O3 AQI                 130
# CO Mean               3006
# CO 1st Max Value       105
# CO 1st Max Hour         24
# CO AQI                 101
# SO2 Mean             11026
# SO2 1st Max Value      813
# SO2 1st Max Hour        24
# SO2 AQI                142
# NO2 Mean             37886
# NO2 1st Max Value     1012
# NO2 1st Max Hour        24
# NO2 AQI                130
# dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 608694    False
# 608695    False
# 608696    False
# 608697    False
# 608698    False
# Length: 608699, dtype: bool

# %%
#EDA

# %%
#univarient

# %%
data.hist(figsize=(10,10))
plt.show()

# %%
columns = ['Date', 'Year', 'Month', 'Day', 'Address', 'State', 'County', 'City',
       'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'CO Mean',
       'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI', 'SO2 Mean',
       'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean',
       'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI']

for i in columns:
    plt.figure(figsize=(14, 5.5))
    sns.countplot(x=data[i])
    print("Distribution of ",i )
    plt.show()
# Out:
# Distribution of  Date
# Distribution of  Year
# Distribution of  Month
# Distribution of  Day
# Distribution of  Address
# Distribution of  State
# Distribution of  County
# Distribution of  City
# Distribution of  O3 Mean
# Distribution of  O3 1st Max Value
# Distribution of  O3 1st Max Hour
# Distribution of  O3 AQI
# Distribution of  CO Mean
# Distribution of  CO 1st Max Value
# Distribution of  CO 1st Max Hour
# Distribution of  CO AQI
# Distribution of  SO2 Mean
# Distribution of  SO2 1st Max Value
# Distribution of  SO2 1st Max Hour
# Distribution of  SO2 AQI
# Distribution of  NO2 Mean
# Distribution of  NO2 1st Max Value
# Distribution of  NO2 1st Max Hour
# Distribution of  NO2 AQI

# %%
#bivarient

# %%
plt.figure(figsize=(10,10))
plt.pie(data[['NO2 AQI','NO2 Mean','NO2 1st Max Value','NO2 1st Max Hour']].value_counts().head(10), labels=data['State'].value_counts().head(10).index, autopct='%1.1f%%')
plt.title('Top 10 State', color='red', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(data['O3 AQI'].value_counts().head(10), labels=data['State'].value_counts().head(10).index, autopct='%1.1f%%')
plt.title('Top 10 state', color='red', fontsize=20)
plt.show()

# %%
plt.figure(figsize = (6,12))
sns.barplot(x ='O3 Mean' , y = 'State' , data = data )
plt.title('O3 Mean of each state')
# Out:
# Text(0.5, 1.0, 'O3 Mean of each state')

# %%
sns.scatterplot(x=data['Year'], y=data['CO AQI'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='CO AQI'>

# %%
sns.scatterplot(x=data['Year'], y=data['NO2 AQI'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='NO2 AQI'>

# %%
sns.scatterplot(x=data['Year'], y=data['SO2 AQI'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='SO2 AQI'>

# %%
data['Date']  = pd.to_datetime(data['Date'])

# %%
data_AQI = data[['State', 'Date', 'NO2 AQI', 'O3 AQI', 'SO2 AQI', 'CO AQI']]
data_AQI_State = data_AQI.groupby('State').mean()
data_AQI_State.reset_index(inplace=True)

plt.rcParams["figure.figsize"] = (18, 12) 

x = np.arange(1,11)

fig, axs = plt.subplots(4, 1)

# Plot for NO2
data_AQI_State.sort_values(by = 'NO2 AQI', ascending = False, inplace = True)
barplot1 = axs[0].bar(x, 'NO2 AQI', data=data_AQI_State[:10], label = 'NO2')
xlabels = data_AQI_State.loc[:10, 'State']
plt.sca(axs[0])
#plt.xticks(x,xlabels) # x axis marks

# Plot for O3
data_AQI_State.sort_values(by = 'O3 AQI', ascending = False, inplace = True)
barplot2 = axs[1].bar(x, 'O3 AQI', data=data_AQI_State[:10], label = 'O3', color = 'red')
xlabels = data_AQI_State.loc[:10, 'State']
plt.sca(axs[1])
#plt.xticks(x, xlabels) # x axis marks

# Plot for SO2
data_AQI_State.sort_values(by = 'SO2 AQI', ascending = False, inplace = True)
barplot3 = axs[2].bar(x, 'SO2 AQI', data=data_AQI_State[:10], label = 'SO2', color = 'green')
xlabels = data_AQI_State.loc[:10, 'State']
plt.sca(axs[2])
#plt.xticks(x, xlabels) # x axis marks

# Plot for CO
data_AQI_State.sort_values(by = 'CO AQI', ascending = False, inplace = True)
barplot4 = axs[3].bar(x, 'CO AQI', data=data_AQI_State[:10], label = 'CO', color = 'purple')
xlabels = data_AQI_State.loc[:10, 'State']
plt.sca(axs[3])
#plt.xticks(x, xlabels) # x axis marks

axs[0].tick_params(axis='both', which='major', labelsize=12) 
axs[1].tick_params(axis='both', which='major', labelsize=12)
axs[2].tick_params(axis='both', which='major', labelsize=12)
axs[3].tick_params(axis='both', which='major', labelsize=12)


# Adding value for each bar
i = 0
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    global i
    for rect in rects:
        height = rect.get_height()
        axs[i].annotate('{:.2f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', size = 12)
    i = i + 1

autolabel(barplot1)
autolabel(barplot2)
autolabel(barplot3)
autolabel(barplot4)

# Space between charts
plt.subplots_adjust(hspace=0.3) 

# Adding plot titles and axis titles
axs[0].set_title('TOP 10 biggest polluters by mean value of AQI for Nitrogen Dioxide (NO2) for 2000-2021', fontsize = 14)
axs[1].set_title('TOP 10 biggest polluters by mean value of AQI for Ozone (O3) for 2000-2021', fontsize = 14)
axs[2].set_title('TOP 10 biggest polluters by mean value of AQI for Sulfur Dioxide (SO2) for 2000-2021', fontsize = 14)
axs[3].set_title('TOP 10 biggest polluters by mean value of AQI for Carbon Monoxide (CO) for 2000-2021', fontsize = 14)
fig.text(0.1, 0.5, 'Mean value of AQI', ha='center', va='center', rotation='vertical', fontsize = 14)
# Out:
# Text(0.1, 0.5, 'Mean value of AQI')

# %%
data_AQI_Year = data_AQI[['Date', 'NO2 AQI', 'O3 AQI', 'SO2 AQI', 'CO AQI']].resample('Y', on = 'Date').mean()
data_AQI_Year.reset_index(inplace=True)

# Plot size
plt.rcParams["figure.figsize"] = (12, 8) 

# Adding plots
fig, ax = plt.subplots()
ax.plot('Date', 'NO2 AQI', data=data_AQI_Year, color = "red", label = "NO2 AQI")
ax.plot('Date', 'O3 AQI', data=data_AQI_Year, color = "blue", label = "O3 AQI")
ax.plot('Date', 'SO2 AQI', data=data_AQI_Year, color = "green", label = "SO2 AQI")
ax.plot('Date', 'CO AQI', data=data_AQI_Year, color = "purple", label = "CO AQI")

# Adding plot title and axis titles
plt.title('Mean value of pollutants for USA in 2000-2021', fontsize = 16)
plt.xlabel("Year", fontsize = 13)
plt.ylabel("Mean value of AQI", fontsize = 13)

# change of font size on both axes
ax.tick_params(axis='both', which='major', labelsize=11) 

# Adding legend
ax.legend()
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -.15), ncol = 6, shadow = True, fontsize = 13)

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
plt.rcParams.update({'font.size': 56})

columns = ('AQI Index values', 'Levels of Health Concern','Possible heath effects')

cell_text = [["0-50", "Good","Minimal Impact"],
["51-100", "Satisfactory","Minor breathing discomfort to sensitive people" ],
["101-200", "Moderate","Breating discomfort to the people with lungs, asthma, and heart diseases"],
["201-300", "Poor","Breating discomfort to most people on prolonged exposure"],
["301-400", "Very Poor","Respiratory illness on prolonged exposure"],
["401-500", "Severe","Affects healthy people and seriously impacts those with existing diseases"]]

colors = [["#66ff33",  "#66ff33", "#66ff33" ],
["#009900", "#009900",  "#009900" ],
["#ffff00", "#ffff00",  "#ffff00" ],
["#ff9900", "#ff9900",  "#ff9900" ],
["#ffad99", "#ffad99",  "#ffad99" ],
["#ff3300", "#ff3300",  "#ff3300" ]]


fig, ax = plt.subplots()

the_table = ax.table(cellText=cell_text, cellColours=colors,
                     colLabels=columns, loc='center' )
ax.axis('off')

the_table.scale(10,10)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#MISSING VALUE

# %%
data.isnull().sum()
# Out:
# Date                   0
# Year                   0
# Month                  0
# Day                    0
# Address                0
# State                  0
# County                 0
# City                   0
# O3 Mean                0
# O3 1st Max Value     111
# O3 1st Max Hour        0
# O3 AQI                 0
# CO Mean                0
# CO 1st Max Value     156
# CO 1st Max Hour        0
# CO AQI                 0
# SO2 Mean               0
# SO2 1st Max Value      0
# SO2 1st Max Hour       0
# SO2 AQI                0
# NO2 Mean               0
# NO2 1st Max Value      0
# NO2 1st Max Hour       0
# NO2 AQI                0
# dtype: int64

# %%
data['O3 1st Max Value']=data['O3 1st Max Value'].fillna(data['O3 1st Max Value'].mean())

# %%
data['CO 1st Max Value']=data['CO 1st Max Value'].fillna(data['CO 1st Max Value'].median())

# %%
data.isnull().sum()
# Out:
# Date                 0
# Year                 0
# Month                0
# Day                  0
# Address              0
# State                0
# County               0
# City                 0
# O3 Mean              0
# O3 1st Max Value     0
# O3 1st Max Hour      0
# O3 AQI               0
# CO Mean              0
# CO 1st Max Value     0
# CO 1st Max Hour      0
# CO AQI               0
# SO2 Mean             0
# SO2 1st Max Value    0
# SO2 1st Max Hour     0
# SO2 AQI              0
# NO2 Mean             0
# NO2 1st Max Value    0
# NO2 1st Max Hour     0
# NO2 AQI              0
# dtype: int64

# %%
#OUTLIER DETECTION

# %%
data.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Day', 'Address', 'State', 'County', 'City',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'CO Mean',
#        'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI', 'SO2 Mean',
#        'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['CO AQI'], orient='h')
plt.show()

# %%
Q1=np.percentile(data['CO AQI'], 25, interpolation='midpoint')
Q2=np.percentile(data['CO AQI'], 50, interpolation='midpoint')
Q3=np.percentile(data['CO AQI'], 75, interpolation='midpoint')
IQR = Q3-Q1
upper_limit=round(Q3+(1.5 * IQR), 4)
lower_limit=round(Q1-(1.5 * IQR), 4)
outlier=[]
for x in data['CO AQI']:
    if (x<lower_limit) or (x>upper_limit):
        outlier.append(x)
print(' Q1: ',Q1,'\n',
      'Q2: ',Q2,'\n',
      'Q3: ',Q3)
print('Upper limit: ',upper_limit)
print('Lower limit: ',lower_limit)
print('Number of outliers in CO AQI: ',len(outlier))
# Out:
#  Q1:  2.0
#  Q2:  5.0
#  Q3:  7.0
# Upper limit:  14.5
# Lower limit:  -5.5
# Number of outliers in CO AQI:  32120

# %%
data['CO AQI']=np.where(data['CO AQI']>upper_limit,upper_limit,np.where(data['CO AQI']<lower_limit,lower_limit,data['CO AQI']))

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['CO AQI'], orient='h')
plt.show()

# %%
data.shape
# Out:
# (608699, 24)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['O3 AQI'], orient='h')
plt.show()

# %%
Q1=np.percentile(data['O3 AQI'], 25, interpolation='midpoint')
Q2=np.percentile(data['O3 AQI'], 50, interpolation='midpoint')
Q3=np.percentile(data['O3 AQI'], 75, interpolation='midpoint')
IQR = Q3-Q1
upper_limit=round(Q3+(1.5 * IQR), 4)
lower_limit=round(Q1-(1.5 * IQR), 4)
outlier=[]
for x in data['O3 AQI']:
    if (x<lower_limit) or (x>upper_limit):
        outlier.append(x)
print(' Q1: ',Q1,'\n',
      'Q2: ',Q2,'\n',
      'Q3: ',Q3)
print('Upper limit: ',upper_limit)
print('Lower limit: ',lower_limit)
print('Number of outliers in O3 AQI: ',len(outlier))
# Out:
#  Q1:  27.0
#  Q2:  35.0
#  Q3:  44.0
# Upper limit:  69.5
# Lower limit:  1.5
# Number of outliers in O3 AQI:  49801

# %%
data['O3 AQI']=np.where(data['O3 AQI']>upper_limit,upper_limit,np.where(data['O3 AQI']<lower_limit,lower_limit,data['O3 AQI']))

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['O3 AQI'], orient='h')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['SO2 AQI'], orient='h')
plt.show()

# %%
Q1=np.percentile(data['SO2 AQI'], 25, interpolation='midpoint')
Q2=np.percentile(data['SO2 AQI'], 50, interpolation='midpoint')
Q3=np.percentile(data['SO2 AQI'], 75, interpolation='midpoint')
IQR = Q3-Q1
upper_limit=round(Q3+(1.5 * IQR), 4)
lower_limit=round(Q1-(1.5 * IQR), 4)
outlier=[]
for x in data['SO2 AQI']:
    if (x<lower_limit) or (x>upper_limit):
        outlier.append(x)
print(' Q1: ',Q1,'\n',
      'Q2: ',Q2,'\n',
      'Q3: ',Q3)
print('Upper limit: ',upper_limit)
print('Lower limit: ',lower_limit)
print('Number of outliers in SO2 AQI: ',len(outlier))
# Out:
#  Q1:  0.0
#  Q2:  1.0
#  Q3:  6.0
# Upper limit:  15.0
# Lower limit:  -9.0
# Number of outliers in SO2 AQI:  61256

# %%
data['SO2 AQI']=np.where(data['SO2 AQI']>upper_limit,upper_limit,np.where(data['SO2 AQI']<lower_limit,lower_limit,data['SO2 AQI']))

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['SO2 AQI'], orient='h')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['NO2 AQI'], orient='h')
plt.show()

# %%
Q1=np.percentile(data['NO2 AQI'], 25, interpolation='midpoint')
Q2=np.percentile(data['NO2 AQI'], 50, interpolation='midpoint')
Q3=np.percentile(data['NO2 AQI'], 75, interpolation='midpoint')
IQR = Q3-Q1
upper_limit=round(Q3+(1.5 * IQR), 4)
lower_limit=round(Q1-(1.5 * IQR), 4)
outlier=[]
for x in data['NO2 AQI']:
    if (x<lower_limit) or (x>upper_limit):
        outlier.append(x)
print(' Q1: ',Q1,'\n',
      'Q2: ',Q2,'\n',
      'Q3: ',Q3)
print('Upper limit: ',upper_limit)
print('Lower limit: ',lower_limit)
print('Number of outliers in SO2 AQI: ',len(outlier))
# Out:
#  Q1:  10.0
#  Q2:  20.0
#  Q3:  31.0
# Upper limit:  62.5
# Lower limit:  -21.5
# Number of outliers in SO2 AQI:  6861

# %%
data['NO2 AQI']=np.where(data['NO2 AQI']>upper_limit,upper_limit,np.where(data['NO2 AQI']<lower_limit,lower_limit,data['NO2 AQI']))

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=data['NO2 AQI'], orient='h')
plt.show()

# %%
#encoding

# %%
data.dtypes
# Out:
# Date                  object
# Year                   int64
# Month                  int64
# Day                    int64
# Address               object
# State                 object
# County                object
# City                  object
# O3 Mean              float64
# O3 1st Max Value     float64
# O3 1st Max Hour        int64
# O3 AQI                 int64
# CO Mean              float64
# CO 1st Max Value     float64
# CO 1st Max Hour        int64
# CO AQI                 int64
# SO2 Mean             float64
# SO2 1st Max Value    float64
# SO2 1st Max Hour       int64
# SO2 AQI                int64
# NO2 Mean             float64
# NO2 1st Max Value    float64
# NO2 1st Max Hour       int64
# NO2 AQI                int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Date','Address','State', 'County', 'City']
data[cols] = data[cols].apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    Date  Year  Month  Day  Address  State  County  City   O3 Mean  \
# 0     0  2000      1    1       38      2      75   102  0.019765
# 1    31  2000      1    2       38      2      75   102  0.015882
# 2    60  2000      1    3       38      2      75   102  0.009353
# 3    91  2000      1    4       38      2      75   102  0.015882
# 4   121  2000      1    5       38      2      75   102  0.007353
#
#    O3 1st Max Value  ...  CO 1st Max Hour  CO AQI  SO2 Mean  \
# 0             0.040  ...               23      25  3.000000
# 1             0.032  ...                0      26  1.958333
# 2             0.016  ...                8      28  5.250000
# 3             0.033  ...               23      34  7.083333
# 4             0.012  ...                2      42  8.708333
#
#    SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI   NO2 Mean  NO2 1st Max Value  \
# 0                9.0                21       13  19.041667               49.0
# ...

# %%
data.dtypes
# Out:
# Date                   int64
# Year                   int64
# Month                  int64
# Day                    int64
# Address                int32
# State                  int32
# County                 int32
# City                   int32
# O3 Mean              float64
# O3 1st Max Value     float64
# O3 1st Max Hour        int64
# O3 AQI                 int64
# CO Mean              float64
# CO 1st Max Value     float64
# CO 1st Max Hour        int64
# CO AQI                 int64
# SO2 Mean             float64
# SO2 1st Max Value    float64
# SO2 1st Max Hour       int64
# SO2 AQI                int64
# NO2 Mean             float64
# NO2 1st Max Value    float64
# NO2 1st Max Hour       int64
# NO2 AQI                int64
# dtype: object

# %%
#FEATURE REDUCTION

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
data=data.drop(['O3 1st Max Value','CO 1st Max Value','SO2 1st Max Value','NO2 1st Max Value'],axis=1)

# %%
print('Number of columns after feature reduction: ',len(data.columns))
# Out:
# Number of columns after feature reduction:  20

# %%
#FEATURE ENGINEERING

# %%
data['Total AQI'] = (data['O3 AQI']+data['SO2 AQI']+data['NO2 AQI']+data['CO AQI'])
data.head(5)
# Out:
#    Date  Year  Month  Day  Address  State  County  City   O3 Mean  \
# 0     0  2000      1    1       38      2      75   102  0.019765
# 1    31  2000      1    2       38      2      75   102  0.015882
# 2    60  2000      1    3       38      2      75   102  0.009353
# 3    91  2000      1    4       38      2      75   102  0.015882
# 4   121  2000      1    5       38      2      75   102  0.007353
#
#    O3 1st Max Hour  ...   CO Mean  CO 1st Max Hour  CO AQI  SO2 Mean  \
# 0               10  ...  0.878947               23      25  3.000000
# 1               10  ...  1.066667                0      26  1.958333
# 2                9  ...  1.762500                8      28  5.250000
# 3                9  ...  1.829167               23      34  7.083333
# 4                9  ...  2.700000                2      42  8.708333
#
#    SO2 1st Max Hour  SO2 AQI   NO2 Mean  NO2 1st Max Hour  NO2 AQI  Total AQI
# ...

# %%
#standaization

# %%
from sklearn.preprocessing import StandardScaler
variables=['Date', 'Year', 'Month', 'Day', 'Address', 'State', 'County', 'City',
       'O3 Mean', 'O3 1st Max Hour', 'O3 AQI', 'CO Mean',
        'CO 1st Max Hour', 'CO AQI', 'SO2 Mean',
        'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean',
        'NO2 1st Max Hour', 'NO2 AQI']
x=data.loc[:,variables].values
y=data.loc[:,['Total AQI']].values
x=StandardScaler().fit_transform(x)
x=pd.DataFrame(x)
x
# Out:
#               0         1         2         3         4         5         6   \
# 0      -1.885043 -1.803256 -1.663934 -1.673359 -1.005440 -1.106687  0.136893
# 1      -1.871177 -1.803256 -1.663934 -1.559812 -1.005440 -1.106687  0.136893
# 2      -1.858206 -1.803256 -1.663934 -1.446265 -1.005440 -1.106687  0.136893
# 3      -1.844340 -1.803256 -1.663934 -1.332719 -1.005440 -1.106687  0.136893
# 4      -1.830921 -1.803256 -1.663934 -1.219172 -1.005440 -1.106687  0.136893
# ...          ...       ...       ...       ...       ...       ...       ...
# 608694  1.619470  1.626686 -0.153648  1.165311  1.495146  1.900207 -0.021118
# 608695  1.619918  1.626686 -0.153648  1.278858  1.495146  1.900207 -0.021118
# 608696  1.620365  1.626686 -0.153648  1.392404  1.495146  1.900207 -0.021118
# 608697  1.620812  1.626686 -0.153648  1.505951  1.495146  1.900207 -0.021118
# 608698  1.621260  1.626686 -0.153648  1.619498  1.495146  1.900207 -0.021118
#
# ...

# %%
#modelling
